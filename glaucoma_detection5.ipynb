# %%
import os
import numpy as np
import pandas as pd
import cv2
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.activations import relu, sigmoid
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
from skimage import morphology

import matplotlib.pyplot as plt

IMAGES_FOLDER = "/kaggle/input/glaucoma-datasets/G1020/Images"
df = pd.read_csv("/kaggle/input/glaucoma-datasets/G1020/G1020.csv")
MASK_FOLDER = "/kaggle/input/glaucoma-datasets/G1020/Masks"

df = df.sample(n=150, random_state=42)
df = df.head(150)

def load_data(df, image_size=(512, 512)):
    images, labels, od_masks, oc_masks = [], [], [], []
    
    print(f"Total images in dataframe: {len(df)}")

    if not os.path.exists(IMAGES_FOLDER):
        print(f"Error: IMAGES_FOLDER not found: {IMAGES_FOLDER}")
    else:
        print(f"IMAGES_FOLDER found: {IMAGES_FOLDER}")

    missing_images = [img for img in df['imageID'] if not os.path.exists(os.path.join(IMAGES_FOLDER, img))]
    if missing_images:
        print(f"Missing images: {len(missing_images)} images not found.")

    def rotate_image(image, angle):
        h, w = image.shape[:2]
        center = (w // 2, h // 2)
        rot_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
        rotated = cv2.warpAffine(image, rot_matrix, (w, h))
        return cv2.resize(rotated, (512, 512)).reshape(512, 512, 1)

    for index, row in df.iterrows():
        img_name = row['imageID']
        label = row['binaryLabels']
        img_path = os.path.join(IMAGES_FOLDER, img_name)

        base_name = os.path.splitext(img_name)[0]  
        mask_name = f"{base_name}.png" 
        mask_path = os.path.join(MASK_FOLDER, mask_name)

        if os.path.exists(img_path) and os.path.exists(mask_path):
            image = cv2.imread(img_path, cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, image_size)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            image = cv2.GaussianBlur(image, (65, 65), 0)
            image = image.reshape(image_size[0], image_size[1], 1)

            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, image_size)

            optic_disc = np.where(mask == 1, 255, 0).astype(np.uint8).reshape(image_size[0], image_size[1], 1)
            optic_cup = np.where(mask == 2, 255, 0).astype(np.uint8).reshape(image_size[0], image_size[1], 1)

            images.append(image)
            labels.append(label)
            od_masks.append(optic_disc)
            oc_masks.append(optic_cup)

            for angle in [45, 90, 170]:
                rotated_img = rotate_image(image, angle)
                rotated_od = rotate_image(optic_disc, angle)
                rotated_oc = rotate_image(optic_cup, angle)

                images.append(rotated_img)
                labels.append(label)
                od_masks.append(rotated_od)
                oc_masks.append(rotated_oc)

        else:
            print(f"Image not found: {img_path}")

    images = np.array(images) / 255.0
    labels = np.array(labels)
    od_masks = np.array(od_masks) / 255.0
    oc_masks = np.array(oc_masks) / 255.0

    print(f"Total images after augmentation: {len(images)}")
    print(f"Total labels: {len(labels)}")
    print(f"Total OD masks: {len(od_masks)}")
    print(f"Total OC masks: {len(oc_masks)}")

    return images, labels, od_masks, oc_masks  
    
images, labels, od_masks, oc_masks = load_data(df)

X_train, X_temp, y_train, y_temp, od_train, od_temp, oc_train, oc_temp = train_test_split(
    images, labels, od_masks, oc_masks, test_size=0.3, random_state=42)
    
X_val, X_test, y_val, y_test, od_val, od_test, oc_val, oc_test = train_test_split(
    X_temp, y_temp, od_temp, oc_temp, test_size=0.5, random_state=42)


def build_unet():
    inputs = layers.Input((512, 512, 1))

    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    c4 = Dropout(0.5)(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = Dropout(0.5)(c5)
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    u6 = UpSampling2D((2, 2))(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = UpSampling2D((2, 2))(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = UpSampling2D((2, 2))(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = UpSampling2D((2, 2))(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    od_outputs = Conv2D(1, (1, 1), activation='sigmoid', name='od_output')(c9)
    oc_outputs = Conv2D(1, (1, 1), activation='sigmoid', name='oc_output')(c9)

    model = Model(inputs=inputs, outputs=[od_outputs, oc_outputs])
    return model

unet = build_unet()
unet.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.0004, momentum=0.95),
    loss='binary_crossentropy',
    metrics=[['accuracy'],['accuracy']]
)

unet.fit(X_train, [od_train, oc_train], epochs=70, batch_size=2, 
         validation_data=(X_val, [od_val, oc_val]))

od_pred, oc_pred = unet.predict(X_test)

print("Prediction complete!")
# Out:
# Total images in dataframe: 150
# IMAGES_FOLDER found: /kaggle/input/glaucoma-datasets/G1020/Images
# Total images after augmentation: 600
# Total labels: 600
# Total OD masks: 600
# Total OC masks: 600
# Epoch 1/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 82s 275ms/step - loss: 0.8604 - oc_output_accuracy: 0.9465 - oc_output_loss: 0.4184 - od_output_accuracy: 0.9837 - od_output_loss: 0.4420 - val_loss: 0.1235 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0302 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0934
# Epoch 2/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.1181 - oc_output_accuracy: 0.9967 - oc_output_loss: 0.0262 - od_output_accuracy: 0.9834 - od_output_loss: 0.0919 - val_loss: 0.1178 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0279 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0899
# Epoch 3/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.1139 - oc_output_accuracy: 0.9966 - oc_output_loss: 0.0249 - od_output_accuracy: 0.9834 - od_output_loss: 0.0890 - val_loss: 0.1143 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0267 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0876
# Epoch 4/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.1094 - oc_output_accuracy: 0.9967 - oc_output_loss: 0.0232 - od_output_accuracy: 0.9835 - od_output_loss: 0.0862 - val_loss: 0.1116 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0258 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0858
# Epoch 5/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.1073 - oc_output_accuracy: 0.9968 - oc_output_loss: 0.0222 - od_output_accuracy: 0.9834 - od_output_loss: 0.0851 - val_loss: 0.1090 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0249 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0841
# Epoch 6/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.1057 - oc_output_accuracy: 0.9966 - oc_output_loss: 0.0223 - od_output_accuracy: 0.9833 - od_output_loss: 0.0834 - val_loss: 0.1061 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0240 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0821
# Epoch 7/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.1026 - oc_output_accuracy: 0.9965 - oc_output_loss: 0.0222 - od_output_accuracy: 0.9835 - od_output_loss: 0.0803 - val_loss: 0.1015 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0226 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0789
# Epoch 8/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0968 - oc_output_accuracy: 0.9965 - oc_output_loss: 0.0205 - od_output_accuracy: 0.9835 - od_output_loss: 0.0763 - val_loss: 0.0950 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0207 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0743
# Epoch 9/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0904 - oc_output_accuracy: 0.9964 - oc_output_loss: 0.0188 - od_output_accuracy: 0.9834 - od_output_loss: 0.0716 - val_loss: 0.0897 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0187 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0709
# Epoch 10/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0827 - oc_output_accuracy: 0.9969 - oc_output_loss: 0.0156 - od_output_accuracy: 0.9835 - od_output_loss: 0.0671 - val_loss: 0.0858 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0178 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0680
# Epoch 11/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0810 - oc_output_accuracy: 0.9964 - oc_output_loss: 0.0164 - od_output_accuracy: 0.9834 - od_output_loss: 0.0646 - val_loss: 0.0851 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0177 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0674
# Epoch 12/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0814 - oc_output_accuracy: 0.9968 - oc_output_loss: 0.0151 - od_output_accuracy: 0.9832 - od_output_loss: 0.0663 - val_loss: 0.0849 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0177 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0672
# Epoch 13/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0790 - oc_output_accuracy: 0.9965 - oc_output_loss: 0.0163 - od_output_accuracy: 0.9836 - od_output_loss: 0.0628 - val_loss: 0.0850 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0177 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0673
# Epoch 14/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0800 - oc_output_accuracy: 0.9967 - oc_output_loss: 0.0153 - od_output_accuracy: 0.9835 - od_output_loss: 0.0648 - val_loss: 0.0854 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0178 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0676
# Epoch 15/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0819 - oc_output_accuracy: 0.9967 - oc_output_loss: 0.0156 - od_output_accuracy: 0.9834 - od_output_loss: 0.0663 - val_loss: 0.0848 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0177 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0671
# Epoch 16/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0794 - oc_output_accuracy: 0.9967 - oc_output_loss: 0.0151 - od_output_accuracy: 0.9832 - od_output_loss: 0.0643 - val_loss: 0.0877 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0183 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0694
# Epoch 17/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0814 - oc_output_accuracy: 0.9965 - oc_output_loss: 0.0164 - od_output_accuracy: 0.9836 - od_output_loss: 0.0650 - val_loss: 0.0851 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0177 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0673
# Epoch 18/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0785 - oc_output_accuracy: 0.9968 - oc_output_loss: 0.0151 - od_output_accuracy: 0.9839 - od_output_loss: 0.0635 - val_loss: 0.0849 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0176 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0673
# Epoch 19/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0802 - oc_output_accuracy: 0.9963 - oc_output_loss: 0.0166 - od_output_accuracy: 0.9835 - od_output_loss: 0.0637 - val_loss: 0.0838 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0173 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0665
# Epoch 20/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - loss: 0.0762 - oc_output_accuracy: 0.9968 - oc_output_loss: 0.0141 - od_output_accuracy: 0.9834 - od_output_loss: 0.0620 - val_loss: 0.0869 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0178 - val_od_output_accuracy: 0.9833 - val_od_output_loss: 0.0691
# Epoch 21/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 223ms/step - loss: 0.0756 - oc_output_accuracy: 0.9964 - oc_output_loss: 0.0148 - od_output_accuracy: 0.9838 - od_output_loss: 0.0608 - val_loss: 0.0826 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.
- val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0190 - val_od_output_accuracy: 0.9832 - val_od_output_loss: 0.0722
# Epoch 69/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 223ms/step - loss: 0.0464 - oc_output_accuracy: 0.9966 - oc_output_loss: 0.0089 - od_output_accuracy: 0.9843 - od_output_loss: 0.0375 - val_loss: 0.0905 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0191 - val_od_output_accuracy: 0.9832 - val_od_output_loss: 0.0714
# Epoch 70/70
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 223ms/step - loss: 0.0480 - oc_output_accuracy: 0.9968 - oc_output_loss: 0.0091 - od_output_accuracy: 0.9839 - od_output_loss: 0.0389 - val_loss: 0.0925 - val_oc_output_accuracy: 0.9962 - val_oc_output_loss: 0.0198 - val_od_output_accuracy: 0.9832 - val_od_output_loss: 0.0727
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 152s 33s/step
# Prediction complete!

# %%
def calculate_cdr(disc_mask, cup_mask):
    disc_area = np.sum(disc_mask)
    cup_area = np.sum(cup_mask)
    disc_mask = (disc_mask > 0).astype(np.uint8)
    cup_mask = (cup_mask > 0).astype(np.uint8)


    return round((2 * cup_area) / disc_area, 4) if disc_area != 0 else 0

def extract_isnt_quadrants(disc_mask, cup_mask):
    disc_mask = disc_mask.squeeze()
    cup_mask = cup_mask.squeeze()

    disc_mask_rotated = np.rot90(disc_mask)
    cup_mask_rotated = np.rot90(cup_mask)

    nrr_mask = cv2.bitwise_xor(disc_mask_rotated, cup_mask_rotated)

    height, width = disc_mask.shape
    I = np.sum(nrr_mask[height//2:, :])
    S = np.sum(nrr_mask[:height//2, :])
    N = np.sum(nrr_mask[:, :width//2])
    T = np.sum(nrr_mask[:, width//2:])

    return round((1 + (I + S)) / (1 + (N + T)), 4) if (N + T) != 0 else 0

def extract_blood_vessels(fundus_image):
    if len(fundus_image.shape) == 2 or fundus_image.shape[2] == 1:
        green_channel = fundus_image[:, :, 0].astype(np.uint8)  # Use the only available channel
    else:
        green_channel = fundus_image[:, :, 1].astype(np.uint8) 
    clahe = cv2.createCLAHE(clipLimit=4.0, tileGridSize=(6,6))
    enhanced = clahe.apply(green_channel)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (15, 15))
    bottom_hat = cv2.morphologyEx(enhanced, cv2.MORPH_BLACKHAT, kernel)

    threshold_value = max(10, 3.15 * np.std(bottom_hat))
    _, vessel_mask = cv2.threshold(bottom_hat, threshold_value, 255, cv2.THRESH_BINARY)

    height, width = vessel_mask.shape
    I = np.sum(vessel_mask[height//2:, :])
    S = np.sum(vessel_mask[:height//2, :])
    N = np.sum(vessel_mask[:, :width//2])
    T = np.sum(vessel_mask[:, width//2:])

    return round((1 + (I + S)) / (1 + (N + T)), 4) if (N + T) != 0 else 0

cdr_train = np.array([calculate_cdr(od, oc) for od, oc in zip(od_train, oc_train)])
isnt_train = np.array([extract_isnt_quadrants(od, oc) for od, oc in zip(od_train, oc_train)])
bvr_train = np.array([extract_blood_vessels(img) for img in X_train])

X_train_combined = np.hstack((cdr_train.reshape(-1,1), isnt_train.reshape(-1,1), bvr_train.reshape(-1,1)))

cdr_test = np.array([calculate_cdr(od, oc) for od, oc in zip(od_test, oc_test)])
isnt_test = np.array([extract_isnt_quadrants(od, oc) for od, oc in zip(od_test, oc_test)])
bvr_test = np.array([extract_blood_vessels(img) for img in X_test])

X_test_combined = np.hstack((cdr_test.reshape(-1,1), isnt_test.reshape(-1,1), bvr_test.reshape(-1,1)))


print(f"X_train_combined shape: {X_train_combined.shape}, y_train shape: {y_train.shape}")
print(f"X_test_combined shape: {X_test_combined.shape}, y_test shape: {y_test.shape}")

svm = SVC(C=10, gamma=1, kernel='rbf', probability=True)
svm.fit(X_train_combined, y_train)
svm_predictions = svm.predict(X_test_combined)

mlp = Sequential([
    Input(shape=(X_train_combined.shape[1],)), 
    Dense(3, activation='relu'),
    Dense(2, activation='relu'),  
    Dense(1, activation='sigmoid')  
])
mlp.compile(optimizer=Adam(), loss=BinaryCrossentropy(), metrics=['accuracy'])
mlp.fit(X_train_combined, y_train, epochs=120, batch_size=2, verbose=1)
mlp_predictions = (mlp.predict(X_test_combined) > 0.5).astype(int).flatten()


adaboost = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3), n_estimators=100)
adaboost = AdaBoostClassifier(n_estimators=50, random_state=20)
adaboost.fit(X_train_combined, y_train)
adaboost_predictions = adaboost.predict(X_test_combined)



svm_accuracy = accuracy_score(y_test, svm_predictions)
mlp_accuracy = accuracy_score(y_test, mlp_predictions)
adaboost_accuracy = accuracy_score(y_test, adaboost_predictions)
print(f"SVM Accuracy: {svm_accuracy}")
print(f"MLP Accuracy: {mlp_accuracy}")
print(f"AdaBoost Accuracy: {adaboost_accuracy}")
# Out:
# X_train_combined shape: (420, 3), y_train shape: (420,)
# X_test_combined shape: (90, 3), y_test shape: (90,)
# Epoch 1/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4433 - loss: 0.7064
# Epoch 2/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6453 - loss: 0.6651
# Epoch 3/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6863 - loss: 0.6351
# Epoch 4/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6376 - loss: 0.6537
# Epoch 5/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6756 - loss: 0.6305
# Epoch 6/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6405 - loss: 0.6495
# Epoch 7/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6385 - loss: 0.6489
# Epoch 8/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6426 - loss: 0.6442
# Epoch 9/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7047 - loss: 0.6034
# Epoch 10/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6496 - loss: 0.6428
# Epoch 11/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6541 - loss: 0.6348
# Epoch 12/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6339 - loss: 0.6492
# Epoch 13/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6511 - loss: 0.6348
# Epoch 14/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6278 - loss: 0.6548
# Epoch 15/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6071 - loss: 0.6686
# Epoch 16/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6597 - loss: 0.6331
# Epoch 17/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7212 - loss: 0.5809
# Epoch 18/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7047 - loss: 0.6023
# Epoch 19/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6818 - loss: 0.6156
# Epoch 20/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6783 - loss: 0.6104
# Epoch 21/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6945 - loss: 0.6005
# Epoch 22/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6403 - loss: 0.6386
# Epoch 23/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6673 - loss: 0.6329
# Epoch 24/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6820 - loss: 0.6053
# Epoch 25/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6599 - loss: 0.6175
# Epoch 26/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6400 - loss: 0.6298
# Epoch 27/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6952 - loss: 0.5969
# Epoch 28/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6521 - loss: 0.6314
# Epoch 29/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6520 - loss: 0.6176
# Epoch 30/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6653 - loss: 0.6118
# Epoch 31/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6627 - loss: 0.6072
# Epoch 32/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6316 - loss: 0.6396
# Epoch 33/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6594 - loss: 0.6155
# Epoch 34/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6332 - loss: 0.6372
# Epoch 35/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6737 - loss: 0.6139
# Epoch 36/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7002 - loss: 0.6074
# Epoch 37/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6585 - loss: 0.6239
# Epoch 38/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6527 - loss: 0.6290
# Epoch 39/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6854 - loss: 0.6004
# Epoch 40/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6486 - loss: 0.6021
# Epoch 41/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6467 - loss: 0.6329
# Epoch 42/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6986 - loss: 0.5915
# Epoch 43/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6175 - loss: 0.6490
# Epoch 44/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6629 - loss: 0.6208
# Epoch 45/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6328 - loss: 0.6274
# Epoch 46/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6696 - loss: 0.6184
# Epoch 47/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6155 - loss: 0.6350
# Epoch 48/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6803 - loss: 0.6086
# Epoch 49/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6990 - loss: 0.5849
# Epoch 50/120
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.