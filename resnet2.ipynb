# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
import os
import json
import cv2
import matplotlib.pyplot as plt
from skimage import io
from skimage.feature import graycomatrix, graycoprops
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import preprocess_input, ResNet50
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D,Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.losses import BinaryFocalCrossentropy
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.models import Sequential, Model 
from keras.optimizers import SGD, Adam
from keras.callbacks import TensorBoard
import keras
import matplotlib.pyplot as plt


IMAGES_FOLDER = "/kaggle/input/glaucoma-datasets/G1020/Images"
df = pd.read_csv("/kaggle/input/glaucoma-datasets/G1020/G1020.csv")
MASK_FOLDER = "/kaggle/input/glaucoma-datasets/G1020/Masks"
HEIGHT, WIDTH = 256, 256
NUM_CLASSES = 2
BATCH_SIZE = 16
EPOCHS = 150
LR = 1e-4
print(df)
# Out:
#              imageID  binaryLabels
# 0        image_0.jpg             0
# 1        image_1.jpg             0
# 2        image_3.jpg             0
# 3        image_4.jpg             0
# 4        image_5.jpg             0
# ...              ...           ...
# 1015  image_3198.jpg             0
# 1016  image_3199.jpg             0
# 1017  image_3201.jpg             1
# 1018  image_3202.jpg             1
# 1019  image_2568.jpg             0
#
# [1020 rows x 2 columns]

# %%
def load_data(df, image_size=(HEIGHT, WIDTH)):
    images, labels = [], []
    od_masks, oc_masks = [], []
    print(f"Total images in dataframe: {len(df)}")

    for index, row in df.iterrows():
        img_name = row['imageID']
        label = row['binaryLabels']
        img_path = os.path.join(IMAGES_FOLDER, img_name)

        base_name = os.path.splitext(img_name)[0]  
        mask_name = f"{base_name}.png" 
        mask_path = os.path.join(MASK_FOLDER, mask_name)
        
        if os.path.exists(img_path) and os.path.exists(mask_path):
            image = cv2.imread(img_path, cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, image_size)
            
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, image_size)
            
            optic_disc = np.where(mask == 1, 255, 0).astype(np.uint8).reshape(image_size[0], image_size[1], 1)
            optic_cup = np.where(mask == 2, 255, 0).astype(np.uint8).reshape(image_size[0], image_size[1], 1)
            
            images.append(image)
            labels.append(label)
            od_masks.append(optic_disc)
            oc_masks.append(optic_cup)
    
    return np.array(images), np.array(labels), np.array(od_masks), np.array(oc_masks)

images, labels, od_masks, oc_masks = load_data(df)
images = images.astype('float32') / 255.0
od_masks = od_masks.astype('float32') / 255.0
oc_masks = oc_masks.astype('float32') / 255.0
labels = to_categorical(labels, num_classes=NUM_CLASSES)

X_train, X_test, y_train, y_test, od_train, od_test, oc_train, oc_test = train_test_split(images, labels, od_masks, oc_masks, test_size=0.3, stratify=labels, random_state=42)

labels_indices = np.argmax(labels, axis=1)
print("Raw label counts:", np.unique(labels_indices, return_counts=True))

class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(labels_indices), y=labels_indices)
class_weights = dict(enumerate(class_weights))

print(f"Dataset Shape: {images.shape}")
print(f"Train Shape: {X_train.shape}, Test Shape: {X_test.shape}")

def calculate_cdr(disc_mask, cup_mask):
    disc_area = np.sum(disc_mask)
    cup_area = np.sum(cup_mask)
    return round((2 * cup_area) / disc_area, 4) if disc_area != 0 else 0

def extract_isnt_quadrants(disc_mask, cup_mask):
    disc_mask = disc_mask.squeeze()
    cup_mask = cup_mask.squeeze()

    disc_mask_rotated = np.rot90(disc_mask)
    cup_mask_rotated = np.rot90(cup_mask)

    nrr_mask = cv2.bitwise_xor(disc_mask_rotated, cup_mask_rotated)
    
    height, width = nrr_mask.shape
    I, S = np.sum(nrr_mask[height//2:, :]), np.sum(nrr_mask[:height//2, :])
    N, T = np.sum(nrr_mask[:, :width//2]), np.sum(nrr_mask[:, width//2:])
    
    return round((1 + (I + S)) / (1 + (N + T)), 4) if (N + T) != 0 else 0

def extract_blood_vessels(fundus_image):
    green_channel = fundus_image[:, :, 1].astype(np.uint8) if fundus_image.shape[2] == 3 else fundus_image[:, :, 0].astype(np.uint8)
    clahe = cv2.createCLAHE(clipLimit=4.0, tileGridSize=(6,6))
    enhanced = clahe.apply(green_channel)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (15, 15))
    bottom_hat = cv2.morphologyEx(enhanced, cv2.MORPH_BLACKHAT, kernel)
    
    threshold_value = max(10, 3.15 * np.std(bottom_hat))
    _, vessel_mask = cv2.threshold(bottom_hat, threshold_value, 255, cv2.THRESH_BINARY)
    
    height, width = vessel_mask.shape
    I, S = np.sum(vessel_mask[height//2:, :]), np.sum(vessel_mask[:height//2, :])
    N, T = np.sum(vessel_mask[:, :width//2]), np.sum(vessel_mask[:, width//2:])
    
    return round((1 + (I + S)) / (1 + (N + T)), 4) if (N + T) != 0 else 0

def extract_features(image, disc_mask, cup_mask):
    return np.array([
        calculate_cdr(disc_mask, cup_mask),
        extract_isnt_quadrants(disc_mask, cup_mask),
        extract_blood_vessels(image)
    ])

def extract_features_batch(images, od_masks, oc_masks):
    return np.array([extract_features(img, od, oc) for img, od, oc in zip(images, od_masks, oc_masks)])

train_features = extract_features_batch(X_train, od_train, oc_train)
test_features = extract_features_batch(X_test, od_test, oc_test)

class HybridDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, X, features, y, batch_size=32, shuffle=True):
        self.X = np.array(X, dtype=np.float32)
        self.features = np.array(features, dtype=np.float32)
        self.y = np.array(y, dtype=np.float32)
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        
    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))
    
    def __getitem__(self, index):
        batch_X = self.X[index*self.batch_size:(index+1)*self.batch_size]
        batch_features = self.features[index*self.batch_size:(index+1)*self.batch_size]
        batch_y = self.y[index*self.batch_size:(index+1)*self.batch_size]
        
        return (batch_X, batch_features), batch_y  

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.X))
            np.random.shuffle(indices)
            self.X = self.X[indices]
            self.features = self.features[indices]
            self.y = self.y[indices]

train_generator = HybridDataGenerator(X_train, train_features, y_train, batch_size=BATCH_SIZE)
test_generator = HybridDataGenerator(X_test, test_features, y_test, batch_size=BATCH_SIZE, shuffle=False)

def build_hybrid_model(base_model, num_features, dropout=0.5, fc_layers=[512, 256], num_classes=2):
    for layer in base_model.layers[:-20]:
        layer.trainable = True

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu', kernel_regularizer='l2')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.6)(x)
    x = Dense(512, activation='relu', kernel_regularizer='l2')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.6)(x)

    feature_input = Input(shape=(num_features,))
    feature_x = Dense(64, activation="relu")(feature_input)

    combined = Concatenate()([x, feature_x])
    predictions = Dense(num_classes, activation='softmax')(combined)
    
    return Model(inputs=[base_model.input, feature_input], outputs=predictions)

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(HEIGHT, WIDTH, 3))
# base_model = EfficientNetB3(weights='imagenet', include_top=False, input_shape=(HEIGHT, WIDTH, 3))

hybrid_model = build_hybrid_model(base_model, num_features=3)

hybrid_model.compile(optimizer=Adam(learning_rate=LR), 
                     loss=BinaryFocalCrossentropy(gamma=2.0), 
                     metrics=["accuracy"])

checkpoint = ModelCheckpoint("resnet50_model.keras", monitor="val_accuracy", verbose=1, save_best_only=True, mode="max")
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
tensorboard = TensorBoard(log_dir="./logs")
callbacks_list = [checkpoint, tensorboard]

hybrid_model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=test_generator,
    callbacks=[checkpoint, reduce_lr, early_stop],
    class_weight=class_weights
)

test_features = extract_features_batch(X_test, od_test, oc_test)
test_loss, test_acc = hybrid_model.evaluate([X_test, test_features], y_test)
y_pred = hybrid_model.predict([X_test, test_features])
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

accuracy = accuracy_score(y_true_labels, y_pred_labels)
report = classification_report(y_true_labels, y_pred_labels, target_names=["Normal", "Glaucoma"])
print("\nClassification Report:\n", report)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Total images in dataframe: 1020
# Raw label counts: (array([0, 1]), array([724, 296]))
# Dataset Shape: (1020, 256, 256, 3)
# Train Shape: (714, 256, 256, 3), Test Shape: (306, 256, 256, 3)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/150
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 656ms/step - accuracy: 0.5135 - loss: 21.0048
# Epoch 1: val_accuracy improved from -inf to 0.70915, saving model to resnet50_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 94s 856ms/step - accuracy: 0.5135 - loss: 21.0009 - val_accuracy: 0.7092 - val_loss: 19.9523 - learning_rate: 1.0000e-04
# Epoch 2/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5400 - loss: 20.2499
# Epoch 2: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.5396 - loss: 20.2485 - val_accuracy: 0.7092 - val_loss: 19.5032 - learning_rate: 1.0000e-04
# Epoch 3/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5832 - loss: 19.7016
# Epoch 3: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.5836 - loss: 19.6984 - val_accuracy: 0.7092 - val_loss: 18.9651 - learning_rate: 1.0000e-04
# Epoch 4/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5837 - loss: 19.1629
# Epoch 4: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.5838 - loss: 19.1618 - val_accuracy: 0.7092 - val_loss: 18.5993 - learning_rate: 1.0000e-04
# Epoch 5/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5645 - loss: 18.8426
# Epoch 5: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.5650 - loss: 18.8381 - val_accuracy: 0.7092 - val_loss: 18.1669 - learning_rate: 1.0000e-04
# Epoch 6/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6215 - loss: 18.2459
# Epoch 6: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.6213 - loss: 18.2445 - val_accuracy: 0.7092 - val_loss: 17.7486 - learning_rate: 1.0000e-04
# Epoch 7/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5933 - loss: 17.8823
# Epoch 7: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.5937 - loss: 17.8792 - val_accuracy: 0.7092 - val_loss: 17.3467 - learning_rate: 1.0000e-04
# Epoch 8/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6402 - loss: 17.3777
# Epoch 8: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.6397 - loss: 17.3765 - val_accuracy: 0.7092 - val_loss: 16.9089 - learning_rate: 1.0000e-04
# Epoch 9/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6726 - loss: 16.9364
# Epoch 9: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.6724 - loss: 16.9352 - val_accuracy: 0.3725 - val_loss: 16.5898 - learning_rate: 1.0000e-04
# Epoch 10/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6953 - loss: 16.4823
# Epoch 10: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.6953 - loss: 16.4813 - val_accuracy: 0.6993 - val_loss: 16.0698 - learning_rate: 1.0000e-04
# Epoch 11/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7489 - loss: 16.0745
# Epoch 11: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.7491 - loss: 16.0732 - val_accuracy: 0.7092 - val_loss: 15.9639 - learning_rate: 1.0000e-04
# Epoch 12/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7864 - loss: 15.7047
# Epoch 12: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.7866 - loss: 15.7020 - val_accuracy: 0.7092 - val_loss: 15.4981 - learning_rate: 1.0000e-04
# Epoch 13/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8162 - loss: 15.2417
# Epoch 13: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8159 - loss: 15.2409 - val_accuracy: 0.7059 - val_loss: 15.1564 - learning_rate: 1.0000e-04
# Epoch 14/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8632 - loss: 14.8823
# Epoch 14: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8628 - loss: 14.8811 - val_accuracy: 0.6863 - val_loss: 14.7642 - learning_rate: 1.0000e-04
# Epoch 15/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8461 - loss: 14.5350
# Epoch 15: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8462 - loss: 14.5328 - val_accuracy: 0.7092 - val_loss: 14.7142 - learning_rate: 1.0000e-04
# Epoch 16/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8996 - loss: 14.1320
# Epoch 16: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8995 - loss: 14.1298 - val_accuracy: 0.7026 - val_loss: 14.1828 - learning_rate: 1.0000e-04
# Epoch 17/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8830 - loss: 13.7583
# Epoch 17: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8830 - loss: 13.7570 - val_accuracy: 0.6993 - val_loss: 13.8870 - learning_rate: 1.0000e-04
# Epoch 18/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9217 - loss: 13.3532
# Epoch 18: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9218 - loss: 13.3513 - val_accuracy: 0.6797 - val_loss: 13.4298 - learning_rate: 1.0000e-04
# Epoch 19/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8893 - loss: 13.0919
# Epoch 19: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8896 - loss: 13.0892 - val_accuracy: 0.7092 - val_loss: 13.1902 - learning_rate: 1.0000e-04
# Epoch 20/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9298 - loss: 12.7082
# Epoch 20: val_accuracy did not improve from 0.70915
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9294 - loss: 12.7067 - val_accuracy: 0.6340 - val_loss: 12.7231 - learning_rate: 1.0000e-04
# Epoch 21/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9255 - loss: 12.3550
# Epoch 21: val_accuracy improved from 0.70915 to 0.71242, saving model to resnet50_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 168ms/step - accuracy: 0.9252 - loss: 12.3532 - val_accuracy: 0.7124 - val_loss: 12.4450 - learning_rate: 1.0000e-04
# Epoch 22/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9376 - loss: 11.9887
# Epoch 22: val_accuracy improved from 0.71242 to 0.71895, saving model to resnet50_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 167ms/step - accuracy: 0.9377 - loss: 11.9867 - val_accuracy: 0.7190 - val_loss: 12.2328 - learning_rate: 1.0000e-04
# Epoch 23/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9191 - loss: 11.6664
# Epoch 23: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9193 - loss: 11.6645 - val_accuracy: 0.6667 - val_loss: 12.0701 - learning_rate: 1.0000e-04
# Epoch 24/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9405 - loss: 11.3097
# Epoch 24: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9404 - loss: 11.3082 - val_accuracy: 0.7026 - val_loss: 11.6304 - learning_rate: 1.0000e-04
# Epoch 25/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9374 - loss: 11.0059
# Epoch 25: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9372 - loss: 11.0048 - val_accuracy: 0.7026 - val_loss: 11.2603 - learning_rate: 1.0000e-04
# Epoch 26/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9285 - loss: 10.7172
# Epoch 26: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9279 - loss: 10.7165 - val_accuracy: 0.6373 - val_loss: 10.7884 - learning_rate: 1.0000e-04
# Epoch 27/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9051 - loss: 10.3981
# Epoch 27: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9057 - loss: 10.3959 - val_accuracy: 0.6732 - val_loss: 10.5743 - learning_rate: 1.0000e-04
# Epoch 28/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9351 - loss: 10.0347
# Epoch 28: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9351 - loss: 10.0333 - val_accuracy: 0.6307 - val_loss: 10.3729 - learning_rate: 1.0000e-04
# Epoch 29/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9388 - loss: 9.7477
# Epoch 29: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9388 - loss: 9.7464 - val_accuracy: 0.6144 - val_loss: 10.3086 - learning_rate: 1.0000e-04
# Epoch 30/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9382 - loss: 9.4340
# Epoch 30: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9383 - loss: 9.4325 - val_accuracy: 0.6405 - val_loss: 9.9158 - learning_rate: 1.0000e-04
# Epoch 31/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9400 - loss: 9.1248
# Epoch 31: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9401 - loss: 9.1232 - val_accuracy: 0.6078 - val_loss: 9.6265 - learning_rate: 1.0000e-04
# Epoch 32/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9529 - loss: 8.8347
# Epoch 32: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9528 - loss: 8.8333 - val_accuracy: 0.6209 - val_loss: 9.2683 - learning_rate: 1.0000e-04
# Epoch 33/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9493 - loss: 8.5677
# Epoch 33: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9490 - loss: 8.5669 - val_accuracy: 0.4935 - val_loss: 9.7848 - learning_rate: 1.0000e-04
# Epoch 34/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9178 - loss: 8.3430
# Epoch 34: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9177 - loss: 8.3413 - val_accuracy: 0.6176 - val_loss: 8.6904 - learning_rate: 1.0000e-04
# Epoch 35/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9292 - loss: 8.0223
# Epoch 35: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9294 - loss: 8.0208 - val_accuracy: 0.6405 - val_loss: 8.4294 - learning_rate: 1.0000e-04
# Epoch 36/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9640 - loss: 7.7191
# Epoch 36: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9638 - loss: 7.7179 - val_accuracy: 0.6536 - val_loss: 8.2269 - learning_rate: 1.0000e-04
# Epoch 37/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9768 - loss: 7.4488
# Epoch 37: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9768 - loss: 7.4475 - val_accuracy: 0.6176 - val_loss: 7.8747 - learning_rate: 1.0000e-04
# Epoch 38/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9818 - loss: 7.1952
# Epoch 38: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9816 - loss: 7.1941 - val_accuracy: 0.6176 - val_loss: 7.6579 - learning_rate: 1.0000e-04
# Epoch 39/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9521 - loss: 6.9649
# Epoch 39: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9521 - loss: 6.9640 - val_accuracy: 0.6471 - val_loss: 7.3175 - learning_rate: 1.0000e-04
# Epoch 40/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9653 - loss: 6.7076
# Epoch 40: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9654 - loss: 6.7062 - val_accuracy: 0.6176 - val_loss: 7.1367 - learning_rate: 1.0000e-04
# Epoch 41/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9705 - loss: 6.4656
# Epoch 41: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9703 - loss: 6.4647 - val_accuracy: 0.6895 - val_loss: 6.9596 - learning_rate: 1.0000e-04
# Epoch 42/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9578 - loss: 6.2481
# Epoch 42: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9578 - loss: 6.2473 - val_accuracy: 0.6503 - val_loss: 6.6640 - learning_rate: 1.0000e-04
# Epoch 43/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9575 - loss: 6.0018
# Epoch 43: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9574 - loss: 6.0008 - val_accuracy: 0.6438 - val_loss: 6.5275 - learning_rate: 1.0000e-04
# Epoch 44/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9491 - loss: 5.7833
# Epoch 44: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9491 - loss: 5.7825 - val_accuracy: 0.6209 - val_loss: 6.1920 - learning_rate: 1.0000e-04
# Epoch 45/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9611 - loss: 5.5597
# Epoch 45: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9611 - loss: 5.5590 - val_accuracy: 0.6699 - val_loss: 6.1540 - learning_rate: 1.0000e-04
# Epoch 46/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9690 - loss: 5.3417
# Epoch 46: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9692 - loss: 5.3405 - val_accuracy: 0.6013 - val_loss: 5.8300 - learning_rate: 1.0000e-04
# Epoch 47/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9741 - loss: 5.1444
# Epoch 47: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9741 - loss: 5.1433 - val_accuracy: 0.6242 - val_loss: 5.6750 - learning_rate: 1.0000e-04
# Epoch 48/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9490 - loss: 5.0226
# Epoch 48: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9492 - loss: 5.0208 - val_accuracy: 0.6928 - val_loss: 5.4473 - learning_rate: 1.0000e-04
# Epoch 49/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9720 - loss: 4.7521
# Epoch 49: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9716 - loss: 4.7516 - val_accuracy: 0.6373 - val_loss: 5.1338 - learning_rate: 1.0000e-04
# Epoch 50/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9460 - loss: 4.5947
# Epoch 50: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9462 - loss: 4.5935 - val_accuracy: 0.6961 - val_loss: 5.1031 - learning_rate: 1.0000e-04
# Epoch 51/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9486 - loss: 4.4017
# Epoch 51: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9487 - loss: 4.4008 - val_accuracy: 0.6732 - val_loss: 4.9049 - learning_rate: 1.0000e-04
# Epoch 52/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9746 - loss: 4.2080
# Epoch 52: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9746 - loss: 4.2070 - val_accuracy: 0.6111 - val_loss: 4.8893 - learning_rate: 1.0000e-04
# Epoch 53/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9802 - loss: 4.0342
# Epoch 53: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9802 - loss: 4.0333 - val_accuracy: 0.6111 - val_loss: 4.7127 - learning_rate: 1.0000e-04
# Epoch 54/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9853 - loss: 3.8691
# Epoch 54: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9849 - loss: 3.8687 - val_accuracy: 0.7124 - val_loss: 4.5487 - learning_rate: 1.0000e-04
# Epoch 55/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9348 - loss: 3.8250
# Epoch 55: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9351 - loss: 3.8230 - val_accuracy: 0.5294 - val_loss: 4.0705 - learning_rate: 1.0000e-04
# Epoch 56/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9370 - loss: 3.6063
# Epoch 56: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9368 - loss: 3.6058 - val_accuracy: 0.4641 - val_loss: 4.4395 - learning_rate: 1.0000e-04
# Epoch 57/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9321 - loss: 3.5039
# Epoch 57: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9321 - loss: 3.5030 - val_accuracy: 0.5882 - val_loss: 3.9943 - learning_rate: 1.0000e-04
# Epoch 58/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9631 - loss: 3.3036
# Epoch 58: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9629 - loss: 3.3029 - val_accuracy: 0.5621 - val_loss: 3.6675 - learning_rate: 1.0000e-04
# Epoch 59/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9648 - loss: 3.1526
# Epoch 59: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9647 - loss: 3.1519 - val_accuracy: 0.6634 - val_loss: 3.6405 - learning_rate: 1.0000e-04
# Epoch 60/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9706 - loss: 3.0276
# Epoch 60: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9706 - loss: 3.0269 - val_accuracy: 0.6503 - val_loss: 3.6174 - learning_rate: 1.0000e-04
# Epoch 61/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9627 - loss: 2.9020
# Epoch 61: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9628 - loss: 2.9013 - val_accuracy: 0.6895 - val_loss: 3.4239 - learning_rate: 1.0000e-04
# Epoch 62/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9841 - loss: 2.7821
# Epoch 62: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9839 - loss: 2.7814 - val_accuracy: 0.6830 - val_loss: 3.2122 - learning_rate: 1.0000e-04
# Epoch 63/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9873 - loss: 2.6380
# Epoch 63: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9872 - loss: 2.6374 - val_accuracy: 0.6699 - val_loss: 3.2377 - learning_rate: 1.0000e-04
# Epoch 64/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9811 - loss: 2.5339
# Epoch 64: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9810 - loss: 2.5335 - val_accuracy: 0.6863 - val_loss: 3.0139 - learning_rate: 1.0000e-04
# Epoch 65/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9561 - loss: 2.4577
# Epoch 65: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9562 - loss: 2.4569 - val_accuracy: 0.6895 - val_loss: 2.9644 - learning_rate: 1.0000e-04
# Epoch 66/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9686 - loss: 2.3286
# Epoch 66: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9687 - loss: 2.3280 - val_accuracy: 0.6667 - val_loss: 2.8556 - learning_rate: 1.0000e-04
# Epoch 67/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9824 - loss: 2.2242
# Epoch 67: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9822 - loss: 2.2242 - val_accuracy: 0.6340 - val_loss: 2.9157 - learning_rate: 1.0000e-04
# Epoch 68/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9711 - loss: 2.1152
# Epoch 68: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9714 - loss: 2.1145 - val_accuracy: 0.5850 - val_loss: 2.6877 - learning_rate: 1.0000e-04
# Epoch 69/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9870 - loss: 2.0132
# Epoch 69: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9869 - loss: 2.0129 - val_accuracy: 0.6340 - val_loss: 2.5959 - learning_rate: 1.0000e-04
# Epoch 70/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9808 - loss: 1.9258
# Epoch 70: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9808 - loss: 1.9252 - val_accuracy: 0.6830 - val_loss: 2.4805 - learning_rate: 1.0000e-04
# Epoch 71/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9907 - loss: 1.8319
# Epoch 71: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9906 - loss: 1.8316 - val_accuracy: 0.6536 - val_loss: 2.3414 - learning_rate: 1.0000e-04
# Epoch 72/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9635 - loss: 1.7804
# Epoch 72: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9636 - loss: 1.7799 - val_accuracy: 0.5980 - val_loss: 2.3078 - learning_rate: 1.0000e-04
# Epoch 73/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9605 - loss: 1.6929
# Epoch 73: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9605 - loss: 1.6927 - val_accuracy: 0.5294 - val_loss: 2.2374 - learning_rate: 1.0000e-04
# Epoch 74/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9725 - loss: 1.6158
# Epoch 74: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9722 - loss: 1.6157 - val_accuracy: 0.6765 - val_loss: 2.2415 - learning_rate: 1.0000e-04
# Epoch 75/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9636 - loss: 1.5456
# Epoch 75: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9638 - loss: 1.5452 - val_accuracy: 0.6307 - val_loss: 2.2482 - learning_rate: 1.0000e-04
# Epoch 76/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9350 - loss: 1.5278
# Epoch 76: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9353 - loss: 1.5271 - val_accuracy: 0.6471 - val_loss: 1.8697 - learning_rate: 1.0000e-04
# Epoch 77/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9308 - loss: 1.4746
# Epoch 77: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9312 - loss: 1.4734 - val_accuracy: 0.6307 - val_loss: 1.7573 - learning_rate: 1.0000e-04
# Epoch 78/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9739 - loss: 1.3450
# Epoch 78: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9740 - loss: 1.3446 - val_accuracy: 0.6634 - val_loss: 1.7905 - learning_rate: 1.0000e-04
# Epoch 79/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9632 - loss: 1.2858
# Epoch 79: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9633 - loss: 1.2853 - val_accuracy: 0.6373 - val_loss: 1.7135 - learning_rate: 1.0000e-04
# Epoch 80/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9631 - loss: 1.2579
# Epoch 80: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9630 - loss: 1.2575 - val_accuracy: 0.6405 - val_loss: 1.6176 - learning_rate: 1.0000e-04
# Epoch 81/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9758 - loss: 1.1653
# Epoch 81: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9753 - loss: 1.1656 - val_accuracy: 0.6275 - val_loss: 1.5598 - learning_rate: 1.0000e-04
# Epoch 82/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9486 - loss: 1.1355
# Epoch 82: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9490 - loss: 1.1351 - val_accuracy: 0.5882 - val_loss: 1.6064 - learning_rate: 1.0000e-04
# Epoch 83/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9671 - loss: 1.0677
# Epoch 83: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9670 - loss: 1.0678 - val_accuracy: 0.6667 - val_loss: 1.5264 - learning_rate: 1.0000e-04
# Epoch 84/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9556 - loss: 1.0465
# Epoch 84: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9556 - loss: 1.0464 - val_accuracy: 0.5261 - val_loss: 1.4440 - learning_rate: 1.0000e-04
# Epoch 85/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9601 - loss: 0.9907
# Epoch 85: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9603 - loss: 0.9904 - val_accuracy: 0.6797 - val_loss: 1.4485 - learning_rate: 1.0000e-04
# Epoch 86/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9839 - loss: 0.9289
# Epoch 86: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9840 - loss: 0.9286 - val_accuracy: 0.6765 - val_loss: 1.5192 - learning_rate: 1.0000e-04
# Epoch 87/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9592 - loss: 0.9131
# Epoch 87: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9591 - loss: 0.9132 - val_accuracy: 0.6863 - val_loss: 1.4585 - learning_rate: 1.0000e-04
# Epoch 88/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9596 - loss: 0.8785
# Epoch 88: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9597 - loss: 0.8783 - val_accuracy: 0.6895 - val_loss: 1.7622 - learning_rate: 1.0000e-04
# Epoch 89/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9654 - loss: 0.8311
# Epoch 89: val_accuracy did not improve from 0.71895
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9651 - loss: 0.8312 - val_accuracy: 0.6928 - val_loss: 1.6177 - learning_rate: 1.0000e-04
# Epoch 90/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9681 - loss: 0.7945
# Epoch 90: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9682 - loss: 0.7943 - val_accuracy: 0.6634 - val_loss: 1.3255 - learning_rate: 5.0000e-05
# Epoch 91/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9822 - loss: 0.7718
# Epoch 91: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9820 - loss: 0.7720 - val_accuracy: 0.6830 - val_loss: 1.2413 - learning_rate: 5.0000e-05
# Epoch 92/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9781 - loss: 0.7554
# Epoch 92: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9781 - loss: 0.7552 - val_accuracy: 0.6863 - val_loss: 1.2443 - learning_rate: 5.0000e-05
# Epoch 93/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9811 - loss: 0.7406
# Epoch 93: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9810 - loss: 0.7405 - val_accuracy: 0.6765 - val_loss: 1.2293 - learning_rate: 5.0000e-05
# Epoch 94/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9861 - loss: 0.7108
# Epoch 94: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9862 - loss: 0.7107 - val_accuracy: 0.6699 - val_loss: 1.2362 - learning_rate: 5.0000e-05
# Epoch 95/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9881 - loss: 0.6945
# Epoch 95: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9880 - loss: 0.6943 - val_accuracy: 0.6438 - val_loss: 1.1656 - learning_rate: 5.0000e-05
# Epoch 96/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9807 - loss: 0.6730
# Epoch 96: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9808 - loss: 0.6728 - val_accuracy: 0.6732 - val_loss: 1.1966 - learning_rate: 5.0000e-05
# Epoch 97/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9892 - loss: 0.6589
# Epoch 97: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9892 - loss: 0.6589 - val_accuracy: 0.6438 - val_loss: 1.1722 - learning_rate: 5.0000e-05
# Epoch 98/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9923 - loss: 0.6372
# Epoch 98: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9923 - loss: 0.6371 - val_accuracy: 0.6569 - val_loss: 1.1160 - learning_rate: 5.0000e-05
# Epoch 99/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9924 - loss: 0.6193
# Epoch 99: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9923 - loss: 0.6193 - val_accuracy: 0.6634 - val_loss: 1.1131 - learning_rate: 5.0000e-05
# Epoch 100/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9899 - loss: 0.6069
# Epoch 100: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9898 - loss: 0.6068 - val_accuracy: 0.6765 - val_loss: 1.1236 - learning_rate: 5.0000e-05
# Epoch 101/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9913 - loss: 0.5821
# Epoch 101: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9914 - loss: 0.5821 - val_accuracy: 0.6536 - val_loss: 1.0773 - learning_rate: 5.0000e-05
# Epoch 102/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9861 - loss: 0.5716
# Epoch 102: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9860 - loss: 0.5716 - val_accuracy: 0.6405 - val_loss: 1.0297 - learning_rate: 5.0000e-05
# Epoch 103/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9714 - loss: 0.5723
# Epoch 103: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9718 - loss: 0.5720 - val_accuracy: 0.6667 - val_loss: 1.0093 - learning_rate: 5.0000e-05
# Epoch 104/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9802 - loss: 0.5542
# Epoch 104: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9803 - loss: 0.5540 - val_accuracy: 0.6373 - val_loss: 1.0207 - learning_rate: 5.0000e-05
# Epoch 105/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9756 - loss: 0.5557
# Epoch 105: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9755 - loss: 0.5556 - val_accuracy: 0.6176 - val_loss: 1.0758 - learning_rate: 5.0000e-05
# Epoch 106/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9774 - loss: 0.5303
# Epoch 106: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9775 - loss: 0.5302 - val_accuracy: 0.6634 - val_loss: 1.2043 - learning_rate: 5.0000e-05
# Epoch 107/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9786 - loss: 0.5151
# Epoch 107: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9786 - loss: 0.5149 - val_accuracy: 0.6373 - val_loss: 1.0537 - learning_rate: 5.0000e-05
# Epoch 108/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9782 - loss: 0.4894
# Epoch 108: val_accuracy did not improve from 0.71895
#
# Epoch 108: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9783 - loss: 0.4893 - val_accuracy: 0.6013 - val_loss: 1.0580 - learning_rate: 5.0000e-05
# Epoch 109/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9889 - loss: 0.4724
# Epoch 109: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9888 - loss: 0.4725 - val_accuracy: 0.6340 - val_loss: 1.0762 - learning_rate: 2.5000e-05
# Epoch 110/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9892 - loss: 0.4663
# Epoch 110: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9893 - loss: 0.4663 - val_accuracy: 0.6471 - val_loss: 1.0743 - learning_rate: 2.5000e-05
# Epoch 111/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9911 - loss: 0.4598
# Epoch 111: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9911 - loss: 0.4598 - val_accuracy: 0.6667 - val_loss: 1.0620 - learning_rate: 2.5000e-05
# Epoch 112/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9941 - loss: 0.4501
# Epoch 112: val_accuracy did not improve from 0.71895
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9942 - loss: 0.4501 - val_accuracy: 0.6765 - val_loss: 1.0472 - learning_rate: 2.5000e-05
# Epoch 113/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9876 - loss: 0.4466
# Epoch 113: val_accuracy did not improve from 0.71895
#
# Epoch 113: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9877 - loss: 0.4466 - val_accuracy: 0.6765 - val_loss: 1.0125 - learning_rate: 2.5000e-05
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 350ms/step - accuracy: 0.7074 - loss: 0.9538
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 380ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.72      0.88      0.79       217
#     Glaucoma       0.34      0.16      0.22        89
#
#     accuracy                           0.67       306
#    macro avg       0.53      0.52      0.50       306
# weighted avg       0.61      0.67      0.62       306
#
# Test Accuracy: 66.67%
# Test Loss: 1.0093, Test Accuracy: 66.67%
